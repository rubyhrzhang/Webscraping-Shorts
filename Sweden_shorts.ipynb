# %% [markdown]
# Here, we are trying to scrape only part of a specific ULR - a table

# %%
import requests
from bs4 import BeautifulSoup

import os
import pandas as pd
from datetime import datetime

# %%
# send a GET request to the ULR
target_url = 'https://www.fi.se/en/our-registers/net-short-positions/'
access_time = datetime.now().strftime("%Y-%m-%d_%H%M%S")
response = requests.get(target_url)
response.raise_for_status() # Check for HTTP errors

# %%
# parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# find the table on the page
table = soup.find('table', id='aktuella')
print(table)
# Out:
# <table id="aktuella"><thead><tr><th>Issuer name</th><th>Issuer LEI code</th><th>Latest position date</th><th class="numeric">Sum short %</th></tr><tbody><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300ZQH0FIF1P0MX67">NIBE Industrier AB</a></td><td>549300ZQH0FIF1P0MX67</td><td>2024-11-15</td><td class="numeric">11.21</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300OWGJPYKC6JF790">Arjo AB (publ)</a></td><td>549300OWGJPYKC6JF790</td><td>2024-11-15</td><td class="numeric">1.36</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300XFXK7DVGDRP410">Moberg Pharma AB (publ)</a></td><td>549300XFXK7DVGDRP410</td><td>2024-11-15</td><td class="numeric">2.44</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300YJUYJ9A24RXL71">Billerud Aktiebolag (publ)</a></td><td>549300YJUYJ9A24RXL71</td><td>2024-11-15</td><td class="numeric">1.14</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300UWE2XN3O7TXX74">Kebni AB (publ)</a></td><td>549300UWE2XN3O7TXX74</td><td>2024-11-15</td><td class="numeric">0.2</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300OJ44CLMRU8YE43">Active Biotech AB (publ)</a></td><td>549300OJ44CLMRU8YE43</td><td>2024-11-12</td><td class="numeric">0.56</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300MBWR5H8SIJLE03">Avanza Bank Holding AB</a></td><td>549300MBWR5H8SIJLE03</td><td>2024-11-15</td><td class="numeric">8.26</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300I9RBIU9DW59H39">Yubico AB</a></td><td>549300I9RBIU9DW59H39</td><td>2024-11-15</td><td class="numeric">4.32</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300UXY7QM6IDCGI12">Sinch AB (publ)</a></td><td>549300UXY7QM6IDCGI12</td><td>2024-11-15</td><td class="numeric">5.64</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300KYLOA3DVEPZ069">Corline Biomedical AB</a></td><td>549300KYLOA3DVEPZ069</td><td>2024-11-15</td><td class="numeric">0.2</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300ZSB0ZCKM1SL747">Logistea AB</a></td><td>549300ZSB0ZCKM1SL747</td><td>2024-11-05</td><td class="numeric">0.2</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=5493006EIYZZYQILKS31">New Wave Group AB</a></td><td>5493006EIYZZYQILKS31</td><td>2024-11-14</td><td class="numeric">3.4</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=54930054EB7KX3MY2Q11">INVISIO AB</a></td><td>54930054EB7KX3MY2Q11</td><td>2024-11-14</td><td class="numeric">0.37</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=2138008KVBXCRJGP6Z26">Infant Bacterial Therapeutics AB</a></td><td>2138008KVBXCRJGP6Z26</td><td>2024-10-28</td><td class="numeric">0.1</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300IULC8F8IGXKI15">Orrön Energy AB</a></td><td>549300IULC8F8IGXKI15</td><td>2024-11-14</td><td class="numeric">3.66</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=529900X0UEM9DOM6FK12">JM AB</a></td><td>529900X0UEM9DOM6FK12</td><td>2024-11-14</td><td class="numeric">10.39</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300BUD7ZPFPKM6856">Smart Eye Aktiebolag (publ)</a></td><td>549300BUD7ZPFPKM6856</td><td>2024-11-14</td><td class="numeric">3.43</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=549300HX9MRFY47AH564">Samhällsbyggnadsbolaget i Norden AB</a></td><td>549300HX9MRFY47AH564</td><td>2024-11-14</td><td class="numeric">13.68</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent/?id=54930045LD4XTJCBGS35">Tobii AB</a></td><td>54930045LD4XTJCBGS35</td><td>2024-11-14</td><td class="numeric">3.13</td></tr><tr><td><a href="/en/our-registers/net-short-positions/emittent ...

# %%
# extract table headers (if any)
headers = [] # will store the header names (i.e., the text content inside the <th> tags) that we extract from the table.
for th in table.find_all('th'): # iterate over all <th> (Table Header Cell - column names) elements:
    headers.append(th.text.strip()) # extract the text from each <th> element:

# extract table rows
rows = []
for tr in table.find_all('tr')[1:]:  # iterate over all the <tr> (Table Rows - rows) but skip the header row 
    cols = tr.find_all('td') # find all <td> (Table Data Cell - regular data cell in a row) elements for each row
    row = [col.text.strip() for col in cols]
    rows.append(row)

# %%
# view as Pandas DataFrame
data = pd.DataFrame(rows, columns=headers)
data
# Out:
#                             Issuer name       Issuer LEI code  \
# 0                    NIBE Industrier AB  549300ZQH0FIF1P0MX67
# 1                        Arjo AB (publ)  549300OWGJPYKC6JF790
# 2               Moberg Pharma AB (publ)  549300XFXK7DVGDRP410
# 3            Billerud Aktiebolag (publ)  549300YJUYJ9A24RXL71
# 4                       Kebni AB (publ)  549300UWE2XN3O7TXX74
# ..                                  ...                   ...
# 370  Hästkällaren Rid Trav & Western AB  894500464CPRG49EGI94
# 371               Spintso International  549300N0YFGUA3NVL475
# 372                       VEONEER, INC.  54930082R4LTC7PERT23
# 373           Hövding Sverige AB (publ)  5493002CWEZ4BUCNG484
# 374                  Brighter AB (publ)  5299001CH8K0RXSYV047
#
#     Latest position date Sum short %
# 0             2024-11-15       11.21
# 1             2024-11-15        1.36
# 2             2024-11-15        2.44
# 3             2024-11-15        1.14
# 4             2024-11-15         0.2
# ..                   ...         ...
# 370           2020-07-10        0.14
# 371           2020-03-13        0.18
# 372           2021-12-16        0.89
# 373           2022-01-19        0.19
# 374           2022-11-09        0.37
#
# [375 rows x 4 columns]

# %%
# save in desired directory
working_directory = os.getcwd()
downloads_dir = os.path.join(working_directory, "downloads")

export_path = os.path.join(downloads_dir, f'Sweden_shorts_{access_time}.csv')
data.to_csv(export_path, index=False)  # index=False avoids writing the row index to the file
